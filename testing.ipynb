# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 11.3/11.3 MB 3.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 510.5/510.5 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 349.3/349.3 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40])

df = pd.DataFrame({
    'Column1': s
})

print(df)
# Out:
#    Column1
# 0       10
# 1       20
# 2       30
# 3       40

# %% [markdown]
# Ah, I understand! You are looking for test questions to evaluate your newly built RAG system.
#
# Since your knowledge base is specifically built on Pandas, NumPy, Scikit-learn, and Matplotlib documentation, you should ask questions that test different aspects of your pipeline. To get an M.Tech-level evaluation, you need to test for accuracy, coding ability, and hallucination prevention.
#
# Here is a curated list of questions you can copy and paste into your Streamlit chat interface, broken down by what they actually test:
#
# 🟢 Level 1: Direct Factual Retrieval (Easy)
# Tests if your vector database (Chroma) is successfully finding the most relevant basic definitions.
#
# "What is a Pandas DataFrame?"
#
# "How do I create an array full of zeros in NumPy?"
#
# "What is the function of train_test_split in scikit-learn?"
#
# 🟡 Level 2: Synthesis & Comparison (Medium)
# Tests if the LLM can pull from multiple retrieved chunks and explain concepts clearly.
#
# "What is the difference between .loc and .iloc in Pandas?"
#
# "How do I handle missing values or NaN data in a Pandas DataFrame?"
#
# "What is the difference between supervised and unsupervised learning in the context of scikit-learn?"
#
# 🟠 Level 3: Code Generation (Hard)
# Tests if the LLM follows your prompt instructions to provide code-focused answers based on the documentation.
#
# "Can you write the code to create a simple scatter plot using Matplotlib with a title and axis labels?"
#
# "Show me how to train a basic Logistic Regression model using scikit-learn."
#
# "How do I group a Pandas DataFrame by a specific column and calculate the mean of the other columns?"
#
# 🔴 Level 4: Hallucination & Boundary Testing (Critical Edge Cases)
# Tests if your strict system prompt ("If you don't know the answer... DO NOT hallucinate") is actually working.
#
# "How do I build a REST API using FastAPI?" (Expected response: "I cannot answer this based on the provided documentation.")
#
# "What is the best way to deploy a React frontend?" (Expected response: Refusal to answer)
#
# "Who is the current CEO of OpenAI?" (Expected response: Refusal to answer)
#
# Try running a few of these through your app and watch the Performance Dashboard tab to see how fast your CPU handles the retrieval and generation.
#
# Which of these categories performed the best when you tested them, and did your system successfully block the out-of-domain questions?
